# %% [markdown]
# <a href="https://colab.research.google.com/github/nick21aka/API.PY/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
from google.colab import files
import io

# Subir el archivo CSV
uploaded = files.upload()

# Asumiendo que el archivo subido es 'Food_Preference.csv'
# Verifica el nombre del archivo si es diferente
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  # Cargar el archivo CSV en un DataFrame
  df_food_preference = pd.read_csv(io.StringIO(uploaded[fn].decode('utf-8')))

# Mostrar las primeras 5 filas del DataFrame
display(df_food_preference.head())
# Out:
#      <input type="file" id="files-6a4e3fb1-1c1f-4e98-b93c-b2d8d547706e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a4e3fb1-1c1f-4e98-b93c-b2d8d547706e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filtrar el DataFrame para comida tradicional y occidental
traditional_food_ages = data_frame[data_frame['Food'] == 'Traditional food']['Age']
western_food_ages = data_frame[data_frame['Food'] == 'Western Food']['Age']

# Crear un gráfico de densidad (KDE) para comparar las distribuciones de edad
plt.figure(figsize=(10, 6))
sns.kdeplot(traditional_food_ages, label='Comida Tradicional', fill=True)
sns.kdeplot(western_food_ages, label='Comida Occidental', fill=True)

plt.title('Distribución de Edad por Preferencia de Comida')
plt.xlabel('Edad')
plt.ylabel('Densidad')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **El gráfico de densidad nos permite ver las curvas de distribución para ambos tipos de comida a lo largo de las diferentes edades, lo que confirmó esta tendencia: picos más pronunciados para la comida occidental en rangos de edad más bajos y para la comida tradicional en rangos de edad más altos.**

# %%
# Calcular la proporción de cada tipo de postre por género
dessert_proportions = data_frame.groupby('Gender')['Dessert'].value_counts(normalize=True)

# Obtener el porcentaje de cada género que pide postre ('Yes')
female_dessert_yes_percentage = dessert_proportions['Female']['Yes'] * 100
male_dessert_yes_percentage = dessert_proportions['Male']['Yes'] * 100

print(f"Porcentaje de mujeres que piden postre: {female_dessert_yes_percentage:.2f}%")
print(f"Porcentaje de hombres que piden postre: {male_dessert_yes_percentage:.2f}%")

if female_dessert_yes_percentage > male_dessert_yes_percentage:
    print("\nLas mujeres tienen una mayor tendencia proporcional a pedir postre.")
elif male_dessert_yes_percentage > female_dessert_yes_percentage:
    print("\nLos hombres tienen una mayor tendencia proporcional a pedir postre.")
else:
    print("\nAmbos géneros tienen una tendencia proporcional similar a pedir postre.")
# Out:
# Porcentaje de mujeres que piden postre: 35.15%
# Porcentaje de hombres que piden postre: 43.70%
#
# Los hombres tienen una mayor tendencia proporcional a pedir postre.

# %%
top_10_nationalities = data_frame['Nationality'].value_counts().head(10)
display(top_10_nationalities)
# Out:
# Nationality
# Indian        238
# Malaysian      10
# Indonesia       7
# Pakistani       3
# MY              2
# Pakistani       2
# Maldivian       2
# Japan           2
# Maldivian       1
# Tanzanian       1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.boxplot(y=data_frame['Age'])
plt.title('Diagrama de Caja de la Distribución de Edades')
plt.ylabel('Edad')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
# Filtrar el DataFrame para menores de 25 años
df_under_25 = data_frame[data_frame['Age'] < 25]

# Preferencias de comida para menores de 25 años
food_preference_under_25 = df_under_25['Food'].value_counts(normalize=True) * 100

# Preferencias de comida generales (ya lo tenemos del análisis previo, pero lo calculamos de nuevo para una comparación clara)
food_preference_general = data_frame['Food'].value_counts(normalize=True) * 100

print("\n--- Preferencias de Comida para Menores de 25 años (%): ---")
display(food_preference_under_25)

print("\n--- Preferencias de Comida Generales (%): ---")
display(food_preference_general)

print("\n--- Comparación: ---")
if food_preference_under_25.idxmax() != food_preference_general.idxmax():
    print(f"El tipo de comida más preferido por los menores de 25 años ({food_preference_under_25.idxmax()}) es diferente al promedio general ({food_preference_general.idxmax()}).")
elif food_preference_under_25.max() > food_preference_general.max():
    print(f"El tipo de comida más preferido es el mismo para ambos grupos ({food_preference_under_25.idxmax()}), pero la preferencia es más acentuada en el grupo de menores de 25 años.")
else:
    print(f"El tipo de comida más preferido es el mismo para ambos grupos ({food_preference_under_25.idxmax()}), y la tendencia es similar o menos acentuada en el grupo de menores de 25 años.")

# Comparación detallada si 'Traditional food' y 'Western Food' están presentes en ambos
if 'Traditional food' in food_preference_under_25 and 'Western Food' in food_preference_under_25 and \
   'Traditional food' in food_preference_general and 'Western Food' in food_preference_general:

    diff_traditional = food_preference_under_25['Traditional food'] - food_preference_general['Traditional food']
    diff_western = food_preference_under_25['Western Food'] - food_preference_general['Western Food']

    print(f"\nLa preferencia por la Comida Tradicional entre menores de 25 años es {diff_traditional:.2f}% {'mayor' if diff_traditional > 0 else 'menor'} que el promedio general.")
    print(f"La preferencia por la Comida Occidental entre menores de 25 años es {diff_western:.2f}% {'mayor' if diff_western > 0 else 'menor'} que el promedio general.")
# Out:
# --- Preferencias de Comida para Menores de 25 años (%): ---
# Food
# Traditional food    67.816092
# Western Food        32.183908
# Name: proportion, dtype: float64
# --- Preferencias de Comida Generales (%): ---
# Food
# Traditional food    82.394366
# Western Food        17.605634
# Name: proportion, dtype: float64
# --- Comparación: ---
# El tipo de comida más preferido es el mismo para ambos grupos (Traditional food), y la tendencia es similar o menos acentuada en el grupo de menores de 25 años.
#
# La preferencia por la Comida Tradicional entre menores de 25 años es -14.58% menor que el promedio general.
# La preferencia por la Comida Occidental entre menores de 25 años es 14.58% mayor que el promedio general.

# %% [markdown]
#  **las edades aproximadamente de 60, 63, 65, 67, 74 y 80 años son las que se identifican visualmente como valores atípicos.**

# %%
# Out:
#                      Timestamp Participant_ID  Gender Nationality  Age  \
# 0  2019/05/07 2:59:13 PM GMT+8         FPS001    Male      Indian   24
# 1  2019/05/07 2:59:45 PM GMT+8         FPS002  Female      Indian   22
# 2  2019/05/07 3:00:05 PM GMT+8         FPS003    Male      Indian   31
# 3  2019/05/07 3:00:11 PM GMT+8         FPS004  Female      Indian   25
# 4  2019/05/07 3:02:50 PM GMT+8         FPS005    Male      Indian   27
#
#                Food              Juice Dessert
# 0  Traditional food        Fresh Juice   Maybe
# 1      Western Food  Carbonated drinks     Yes
# 2      Western Food        Fresh Juice   Maybe
# 3  Traditional food        Fresh Juice   Maybe
# 4  Traditional food        Fresh Juice   Maybe

# %%
data_frame.shape
# Out:
# (288, 8)

# %%
# Revisión de los tipos de datos
data_frame.dtypes
# Out:
# Timestamp         object
# Participant_ID    object
# Gender            object
# Nationality       object
# Age                int64
# Food              object
# Juice             object
# Dessert           object
# dtype: object

# %%
# Valores nulos
for feature in data_frame.columns:
    print('Total de valores nulos de', feature, '=', data_frame[feature].isna().sum())
# Out:
# Total de valores nulos de Timestamp = 0
# Total de valores nulos de Participant_ID = 0
# Total de valores nulos de Gender = 0
# Total de valores nulos de Nationality = 0
# Total de valores nulos de Age = 0
# Total de valores nulos de Food = 0
# Total de valores nulos de Juice = 0
# Total de valores nulos de Dessert = 0

# %%
# Aplica la técnica 1 de tratamiento de nulos
data_frame = data_frame.dropna()
data_frame.shape
# Out:
# (284, 8)

# %%
data_frame.describe()
# Out:
#               Age
# count  284.000000
# mean    30.654930
# std     11.244501
# min      8.000000
# 25%     24.000000
# 50%     28.000000
# 75%     37.000000
# max     80.000000

# %%
print('Mínimo:',data_frame['Age'].min())
print('Máximo:',data_frame['Age'].max())
print('Promedio:',data_frame['Age'].mean())
print('STD:',data_frame['Age'].std())
print(data_frame.Age.quantile([.25, .5, .75]))
print('*******')
print('Mínimo:',min(data_frame['Age']))
print('Máximo:',max(data_frame['Age']))
# Out:
# Mínimo: 8
# Máximo: 80
# Promedio: 30.654929577464788
# STD: 11.24450130222142
# 0.25    24.0
# 0.50    28.0
# 0.75    37.0
# Name: Age, dtype: float64
# *******
# Mínimo: 8
# Máximo: 80

# %%
data_frame.describe(include="all")
# Out:
#                           Timestamp Participant_ID  Gender Nationality  \
# count                           284            284     284         284
# unique                          281            284       2          26
# top     2019/05/07 3:07:36 PM GMT+8         FPS288  Female      Indian
# freq                              2              1     165         238
# mean                            NaN            NaN     NaN         NaN
# std                             NaN            NaN     NaN         NaN
# min                             NaN            NaN     NaN         NaN
# 25%                             NaN            NaN     NaN         NaN
# 50%                             NaN            NaN     NaN         NaN
# 75%                             NaN            NaN     NaN         NaN
# max                             NaN            NaN     NaN         NaN
#
#                Age              Food        Juice Dessert
# ...

# %%
# Considerando solo las columnas de tipo object
import numpy as np
data_frame.describe(include=[object])
# Out:
#                           Timestamp Participant_ID  Gender Nationality  \
# count                           284            284     284         284
# unique                          281            284       2          26
# top     2019/05/07 3:07:36 PM GMT+8         FPS288  Female      Indian
# freq                              2              1     165         238
#
#                     Food        Juice Dessert
# count                284          284     284
# unique                 2            2       3
# top     Traditional food  Fresh Juice   Maybe
# freq                 234          252     122

# %%
# Obtener total de pedidos considerando tipo de comida y género
data_frame.groupby('Gender')['Food'].value_counts()
# Out:
# Gender  Food
# Female  Traditional food    144
#         Western Food         21
# Male    Traditional food     90
#         Western Food         29
# Name: count, dtype: int64

# %%
# Obtener total de alternativas de postre por género
data_frame.groupby('Gender')['Dessert'].value_counts()
# Out:
# Gender  Dessert
# Female  Maybe      72
#         Yes        58
#         No         35
# Male    Yes        52
#         Maybe      50
#         No         17
# Name: count, dtype: int64

# %%
# Para comprobar los resultados anteriores
data_frame.groupby(data_frame.Gender).count()
# Out:
#         Timestamp  Participant_ID  Nationality  Age  Food  Juice  Dessert
# Gender
# Female        165             165          165  165   165    165      165
# Male          119             119          119  119   119    119      119

# %%
# ¿Quiénes piden más postres, los hombres o las mujeres?
data_frame[data_frame.Dessert == 'Yes'].groupby('Gender')['Dessert'].count()
# Out:
# Gender
# Female    58
# Male      52
# Name: Dessert, dtype: int64

# %%
# Visualizamos de forma rápida las características de entrada, eliminando las columnas que no interesan
data_frame.drop(['Timestamp', 'Participant_ID'], axis=1).hist()
plt.show()

# %%
def getGraficoBarras(label_x, label_y, title, feature):
    x_values = data_frame[feature].unique()
    y_values = data_frame[feature].value_counts().tolist()
    plt.bar(x_values, y_values)
    plt.title(title)
    plt.xlabel(label_x)
    plt.ylabel(label_y)
    plt.show()
getGraficoBarras('Tipos de comida', 'Nro.Obsevaciones', 'Total de observaciones por tipo de comida', 'Food')

# %%
tipos = data_frame['Food'].unique()
total = data_frame['Food'].value_counts().tolist()
explode = [0.4 if total[0] == max(total) else 0, 0.4 if total[1] == max(total) else 0] # Destacar algunos
plt.pie(total, labels=tipos, explode = explode, autopct='%1.1f%%', shadow=True, startangle=90)
plt.title('Distribución de tipos de comida')
plt.show()

# %%
# Respondiendo, gráficamente a: ¿Quiénes piden más postres, los hombres o las mujeres?
df_pie = pd.DataFrame(data_frame[data_frame.Dessert == 'Yes'].groupby('Gender')['Dessert'].count())
colores = ["#EE6055","#60D394"]
plt.pie(np.array(df_pie).ravel(), labels=[df_pie.index[0],df_pie.index[1]],
autopct='%1.1f%%', shadow=True, startangle=90, colors = colores)
plt.title('Distribución por género de solicitud de postres')
plt.show()

# %%
from matplotlib import cm
from matplotlib import colors
df_pie = pd.DataFrame(data_frame[data_frame.Dessert == 'Yes'].groupby('Gender')['Dessert'].count())
normdata = colors.Normalize(min(df_pie.Dessert), max(df_pie.Dessert))
colormap = cm.get_cmap("Blues")
colores =colormap(normdata(np.array(df_pie).ravel()))
plt.pie(np.array(df_pie).ravel(), labels=[df_pie.index[0],df_pie.index[1]],
autopct='%1.1f%%', shadow=True, startangle=90, colors = colores)
plt.title('Distribución por género de solicitud de postres')
plt.show()
# Out:
# /tmp/ipykernel_710/1845310765.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colormap = cm.get_cmap("Blues")

# %%
# Gráfico de densidad de edades
x_values = data_frame.Age.unique()
y_values = data_frame.Age.value_counts().tolist()
plt.scatter(x_values, y_values, marker='o');
#plt.plot(x_values, y_values)
plt.title('Densidad de edades')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()
